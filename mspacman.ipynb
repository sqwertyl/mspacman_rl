# %%
import gymnasium as gym
import numpy as np

# %% [markdown]
# ### action space
# | Value | Meaning | Value | Meaning | Value | Meaning |
# | ----- | ------- | ----- | ------- | ----- | ------- |
# | 0 | NO OP | 1 | UP | 2 | RIGHT |
# | 3 | LEFT | 4 | DOWN | 5 | UP RIGHT |
# | 6 | UP LEFT | 7 | DOWN RIGHT | 8 | DOWN LEFT |
#
# ### rgb colors
# | Entity | RGB values | Entity | RGB values |
# | ------ | ---------- | ------ | ---------- |
# | MsPacman | 210,164,74 | Pink Ghost | 198,89,179 |
# | Red Ghost | 200,72,72 | Cyan Ghost | 84,184,153 |
# | Orange Ghost | 180,122,48 |

# %%
# env = gym.make("MsPacman-v4", render_mode="human")

# num_episodes = 100;
# observation, info = env.reset()
# rewards = []

# for episode in range(1):
#     done = False;
#     reward_sum = 0;
#     lives = 3;
#     while not done:
#         action = env.action_space.sample()
#         observation, reward, terminated, truncated, info = env.step(action)
#         reward_sum += reward;
#         lives = info['lives']
#         if terminated or truncated or lives == 0:
#             done = True;
#             rewards.append(reward_sum)
#             print(f"episode: {episode} reward = {reward_sum}")
#             observation, info = env.reset()
# env.close()

# %%
class Pacman:
    def __init__(self):
        self.env = gym.make("MsPacman-v4", render_mode="human")
        self.env.reset()

    def find_ghosts(self, obs_space):
        # ghost colors
        ghost_colors = {
            "red": np.array([200, 72, 72]),
            "orange": np.array([180, 122, 48]),
            "pink": np.array([198, 89, 179]),
            "cyan": np.array([84, 184, 153]),
        }
        screen_pixels = np.array(obs_space)

        # dictionary where each color maps to a list of (x, y) coordinates
        ghost_coords = {}

        # for each color, find their x and y location on the screen
        for color_name, color_value in ghost_colors.items():
            ghost_indices = np.where(np.all(screen_pixels == color_value, axis=-1))
            ghost_coords[color_name] = list(zip(*ghost_indices))

        return ghost_coords
    
    def find_mspacman(self, obs_space):
        # find the location of ms pacman (every pixel that is yellow)
        pacman_coords = np.where(np.all(obs_space == np.array([210, 164, 74]), axis=-1))
        return list(zip(*pacman_coords))

    def closest_ghost(self, obs_space):
        # find current ghost and mspacman pixel coords
        ghost_coords = self.find_ghosts(obs_space)
        mspacman_coords = self.find_mspacman(obs_space)

        closest_ghost = None
        closest_distance = 1000000

        # for each ghost, find the distance between it and ms pacman
        for ghost_color, ghost_coord_list in ghost_coords.items():
            # for each coordinate in the list, find the distance between it and ms pacman
            for ghost_coord in ghost_coord_list:
                # distance = np.linalg.norm(np.array(mspacman_coords) - np.array(ghost_coord))
                for pacman_coord in mspacman_coords:
                    # print(f'pacman_coord: {pacman_coord} ghost_coord: {ghost_coord}')
                    distance = np.linalg.norm(np.array(pacman_coord) - np.array(ghost_coord))
                    if distance < closest_distance:
                        closest_distance = distance
                        closest_ghost = ghost_color

        return closest_ghost, closest_distance

    def run(self, num_episodes):
        rewards = []
        observation, info = self.env.reset()  
        for episode in range(num_episodes):
            done = False
            lives = 3
            reward_sum = 0
            while not done:
                # for now take random action
                action = self.env.action_space.sample()
                # take a step in environment using above action
                observation, reward, terminated, truncated, info = self.env.step(action)
                # find closest ghost & distance
                closest_ghost, closest_distance = self.closest_ghost(observation)
                lives = info['lives']
                reward_sum += reward
                print(f'episode: {episode} action: {action} reward: {reward} done: {done} info: {info} closest_ghost: {closest_ghost} closest_distance: {closest_distance}')
                # if in terminal state or no more lives, end episode
                if terminated or truncated or lives == 0:
                    done = True;
                    rewards.append(reward_sum)
                    print(f"episode: {episode} reward = {reward_sum}")
                    observation, info = self.env.reset()
        self.env.close()

# %%
game = Pacman()
game.run(1)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 3, 'frame_number': 3} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 7, 'frame_number': 7} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 11, 'frame_number': 11} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 13, 'frame_number': 13} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 15, 'frame_number': 15} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 17, 'frame_number': 17} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 19, 'frame_number': 19} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 21, 'frame_number': 21} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 25, 'frame_number': 25} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 27, 'frame_number': 27} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 31, 'frame_number': 31} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 34, 'frame_number': 34} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 37, 'frame_number': 37} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 39, 'frame_number': 39} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 43, 'frame_number': 43} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 46, 'frame_number': 46} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 48, 'frame_number': 48} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 52, 'frame_number': 52} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 56, 'frame_number': 56} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 58, 'frame_number': 58} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 62, 'frame_number': 62} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 65, 'frame_number': 65} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 68, 'frame_number': 68} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 70, 'frame_number': 70} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 74, 'frame_number': 74} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 78, 'frame_number': 78} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 82, 'frame_number': 82} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 86, 'frame_number': 86} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 90, 'frame_number': 90} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 92, 'frame_number': 92} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 95, 'frame_number': 95} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 98, 'frame_number': 98} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 100, 'frame_number': 100} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 103, 'frame_number': 103} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 107, 'frame_number': 107} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 109, 'frame_number': 109} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 113, 'frame_number': 113} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 116, 'frame_number': 116} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 120, 'frame_number': 120} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 123, 'frame_number': 123} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 126, 'frame_number': 126} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 128, 'frame_number': 128} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 132, 'frame_number': 132} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 134, 'frame_number': 134} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 137, 'frame_number': 137} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 139, 'frame_number': 139} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 142, 'frame_number': 142} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 146, 'frame_number': 146} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 150, 'frame_number': 150} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 154, 'frame_number': 154} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 157, 'frame_number': 157} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 159, 'frame_number': 159} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 161, 'frame_number': 161} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 165, 'frame_number': 165} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 168, 'frame_number': 168} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 172, 'frame_number': 172} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 175, 'frame_number': 175} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 178, 'frame_number': 178} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 180, 'frame_number': 180} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 183, 'frame_number': 183} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 187, 'frame_number': 187} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 189, 'frame_number': 189} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 192, 'frame_number': 192} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 195, 'frame_number': 195} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 198, 'frame_number': 198} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 202, 'frame_number': 202} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 204, 'frame_number': 204} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 207, 'frame_number': 207} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 209, 'frame_number': 209} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 211, 'frame_number': 211} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 215, 'frame_number': 215} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 217, 'frame_number': 217} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 221, 'frame_number': 221} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 223, 'frame_number': 223} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 226, 'frame_number': 226} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 230, 'frame_number': 230} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 232, 'frame_number': 232} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 236, 'frame_number': 236} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 240, 'frame_number': 240} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 243, 'frame_number': 243} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 246, 'frame_number': 246} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 249, 'frame_number': 249} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 252, 'frame_number': 252} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 254, 'frame_number': 254} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 256, 'frame_number': 256} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 258, 'frame_number': 258} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 261, 'frame_number': 261} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 263, 'frame_number': 263} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 265, 'frame_number': 265} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 268, 'frame_number': 268} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 271, 'frame_number': 271} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 273, 'frame_number': 273} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 276, 'frame_number': 276} closest_ghost: orange closest_distance: 10.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 278, 'frame_number': 278} closest_ghost: cyan closest_distance: 13.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 282, 'frame_number': 282} closest_ghost: orange closest_distance: 13.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 285, 'frame_number': 285} closest_ghost: cyan closest_distance: 18.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 288, 'frame_number': 288} closest_ghost: cyan closest_distance: 20.024984394500787
# episode: 0 action: 4 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 290, 'frame_number': 290} closest_ghost: cyan closest_distance: 22.02271554554524
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 294, 'frame_number': 294} closest_ghost: pink closest_distance: 20.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 296, 'frame_number': 296} closest_ghost: orange closest_distance: 23.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 299, 'frame_number': 299} closest_ghost: cyan closest_distance: 23.345235059857504
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 303, 'frame_number': 303} closest_ghost: cyan closest_distance: 23.769728648009426
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 305, 'frame_number': 305} closest_ghost: red closest_distance: 49.20365840057018
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 308, 'frame_number': 308} closest_ghost: orange closest_distance: 26.92582403567252
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 game = Pacman()
# ----> 2 game.run(1)
#
# Cell In[3], line 66, in Pacman.run(self, num_episodes)
#      64 observation, reward, terminated, truncated, info = self.env.step(action)
#      65 # find closest ghost & distance
# ---> 66 closest_ghost, closest_distance = self.closest_ghost(observation)
#      67 lives = info['lives']
#      68 reward_sum += reward
#
# Cell In[3], line 46, in Pacman.closest_ghost(self, obs_space)
#      42 for ghost_coord in ghost_coord_list:
#      43     # distance = np.linalg.norm(np.array(mspacman_coords) - np.array(ghost_coord))
#      44     for pacman_coord in mspacman_coords:
#      45         # print(f'pacman_coord: {pacman_coord} ghost_coord: {ghost_coord}')
# ---> 46         distance = np.linalg.norm(np.array(pacman_coord) - np.array(ghost_coord))
#      47         if distance < closest_distance:
#      48             closest_distance = distance
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
