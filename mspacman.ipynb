# %%
import gymnasium as gym
import numpy as np

# %% [markdown]
# ### action space
# | Value | Meaning | Value | Meaning | Value | Meaning |
# | ----- | ------- | ----- | ------- | ----- | ------- |
# | 0 | NO OP | 1 | UP | 2 | RIGHT |
# | 3 | LEFT | 4 | DOWN | 5 | UP RIGHT |
# | 6 | UP LEFT | 7 | DOWN RIGHT | 8 | DOWN LEFT |
#
# ### rgb colors
# | Entity | RGB values | Entity | RGB values |
# | ------ | ---------- | ------ | ---------- |
# | MsPacman | 210,164,74 | Pink Ghost | 198,89,179 |
# | Red Ghost | 200,72,72 | Cyan Ghost | 84,184,153 |
# | Orange Ghost | 180,122,48 |

# %%
# env = gym.make("MsPacman-v4", render_mode="human")

# num_episodes = 100;
# observation, info = env.reset()
# rewards = []

# for episode in range(1):
#     done = False;
#     reward_sum = 0;
#     lives = 3;
#     while not done:
#         action = env.action_space.sample()
#         observation, reward, terminated, truncated, info = env.step(action)
#         reward_sum += reward;
#         lives = info['lives']
#         if terminated or truncated or lives == 0:
#             done = True;
#             rewards.append(reward_sum)
#             print(f"episode: {episode} reward = {reward_sum}")
#             observation, info = env.reset()
# env.close()

# %%
class Pacman:
    def __init__(self):
        self.env = gym.make("MsPacman-v4", render_mode="human")
        self.env.reset()

    def find_ghosts(self, obs_space):
        # ghost colors
        ghost_colors = {
            "red": np.array([200, 72, 72]),
            "orange": np.array([180, 122, 48]),
            "pink": np.array([198, 89, 179]),
            "cyan": np.array([84, 184, 153]),
        }
        screen_pixels = np.array(obs_space)

        # dictionary where each color maps to a list of (x, y) coordinates
        ghost_coords = {}

        # for each color, find their x and y location on the screen
        for color_name, color_value in ghost_colors.items():
            ghost_indices = np.where(np.all(screen_pixels == color_value, axis=-1))
            ghost_coords[color_name] = list(zip(*ghost_indices))

        return ghost_coords
    
    def find_mspacman(self, obs_space):
        # find the location of ms pacman (every pixel that is yellow)
        pacman_coords = np.where(np.all(obs_space == np.array([210, 164, 74]), axis=-1))
        return list(zip(*pacman_coords))

    def closest_ghost(self, obs_space):
        # find current ghost and mspacman pixel coords
        ghost_coords = self.find_ghosts(obs_space)
        mspacman_coords = self.find_mspacman(obs_space)

        closest_ghost = None
        closest_distance = 1000000

        # for each ghost, find the distance between it and ms pacman
        for ghost_color, ghost_coord_list in ghost_coords.items():
            # for each coordinate in the list, find the distance between it and ms pacman
            for ghost_coord in ghost_coord_list:
                # distance = np.linalg.norm(np.array(mspacman_coords) - np.array(ghost_coord))
                for pacman_coord in mspacman_coords:
                    # print(f'pacman_coord: {pacman_coord} ghost_coord: {ghost_coord}')
                    distance = np.linalg.norm(np.array(pacman_coord) - np.array(ghost_coord))
                    if distance < closest_distance:
                        closest_distance = distance
                        closest_ghost = ghost_color

        return closest_ghost, closest_distance

    def run(self, num_episodes):

        rewards = []
        for episode in range(num_episodes):
            done = False
            observation = self.env.reset()
            lives = 3
            reward_sum = 0
            while not done:
                action = self.env.action_space.sample()
                observation, reward, terminated, truncated, info = self.env.step(action)
                closest_ghost, closest_distance = self.closest_ghost(observation)
                lives = info['lives']
                reward_sum += reward
                print(f'episode: {episode} action: {action} reward: {reward} done: {done} info: {info} closest_ghost: {closest_ghost} closest_distance: {closest_distance}')
                if terminated or truncated or lives == 0:
                    done = True;
                    rewards.append(reward_sum)
                    print(f"episode: {episode} reward = {reward_sum}")
                    observation, info = self.env.reset()
        self.env.close()

# %%
game = Pacman()
game.run(1)
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 4, 'frame_number': 4} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 6, 'frame_number': 6} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 10, 'frame_number': 10} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 12, 'frame_number': 12} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 16, 'frame_number': 16} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 20, 'frame_number': 20} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 24, 'frame_number': 24} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 28, 'frame_number': 28} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 32, 'frame_number': 32} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 34, 'frame_number': 34} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 36, 'frame_number': 36} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 39, 'frame_number': 39} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 43, 'frame_number': 43} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 45, 'frame_number': 45} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 47, 'frame_number': 47} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 51, 'frame_number': 51} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 55, 'frame_number': 55} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 57, 'frame_number': 57} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 60, 'frame_number': 60} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 62, 'frame_number': 62} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 66, 'frame_number': 66} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 68, 'frame_number': 68} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 71, 'frame_number': 71} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 75, 'frame_number': 75} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 79, 'frame_number': 79} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 83, 'frame_number': 83} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 86, 'frame_number': 86} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 88, 'frame_number': 88} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 92, 'frame_number': 92} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 96, 'frame_number': 96} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 98, 'frame_number': 98} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 102, 'frame_number': 102} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 106, 'frame_number': 106} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 109, 'frame_number': 109} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 111, 'frame_number': 111} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 115, 'frame_number': 115} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 117, 'frame_number': 117} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 120, 'frame_number': 120} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 124, 'frame_number': 124} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 126, 'frame_number': 126} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 129, 'frame_number': 129} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 133, 'frame_number': 133} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 135, 'frame_number': 135} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 137, 'frame_number': 137} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 139, 'frame_number': 139} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 143, 'frame_number': 143} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 145, 'frame_number': 145} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 148, 'frame_number': 148} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 152, 'frame_number': 152} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 156, 'frame_number': 156} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 159, 'frame_number': 159} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 162, 'frame_number': 162} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 164, 'frame_number': 164} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 166, 'frame_number': 166} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 169, 'frame_number': 169} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 172, 'frame_number': 172} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 174, 'frame_number': 174} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 177, 'frame_number': 177} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 181, 'frame_number': 181} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 185, 'frame_number': 185} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 187, 'frame_number': 187} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 191, 'frame_number': 191} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 194, 'frame_number': 194} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 197, 'frame_number': 197} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 199, 'frame_number': 199} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 202, 'frame_number': 202} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 205, 'frame_number': 205} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 209, 'frame_number': 209} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 213, 'frame_number': 213} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 215, 'frame_number': 215} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 218, 'frame_number': 218} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 220, 'frame_number': 220} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 223, 'frame_number': 223} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 227, 'frame_number': 227} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 230, 'frame_number': 230} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 233, 'frame_number': 233} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 235, 'frame_number': 235} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 239, 'frame_number': 239} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 243, 'frame_number': 243} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 247, 'frame_number': 247} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 251, 'frame_number': 251} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 253, 'frame_number': 253} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 255, 'frame_number': 255} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 257, 'frame_number': 257} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 261, 'frame_number': 261} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 263, 'frame_number': 263} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 265, 'frame_number': 265} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 268, 'frame_number': 268} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 272, 'frame_number': 272} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 275, 'frame_number': 275} closest_ghost: cyan closest_distance: 12.041594578792296
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 279, 'frame_number': 279} closest_ghost: orange closest_distance: 13.038404810405298
# episode: 0 action: 0 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 283, 'frame_number': 283} closest_ghost: pink closest_distance: 13.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 286, 'frame_number': 286} closest_ghost: pink closest_distance: 15.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 289, 'frame_number': 289} closest_ghost: pink closest_distance: 17.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 292, 'frame_number': 292} closest_ghost: orange closest_distance: 20.024984394500787
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 296, 'frame_number': 296} closest_ghost: orange closest_distance: 23.08679276123039
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 298, 'frame_number': 298} closest_ghost: pink closest_distance: 22.090722034374522
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 302, 'frame_number': 302} closest_ghost: pink closest_distance: 23.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 305, 'frame_number': 305} closest_ghost: red closest_distance: 45.27692569068709
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 309, 'frame_number': 309} closest_ghost: red closest_distance: 45.79301256742124
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 311, 'frame_number': 311} closest_ghost: cyan closest_distance: 21.213203435596427
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 314, 'frame_number': 314} closest_ghost: pink closest_distance: 23.345235059857504
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 316, 'frame_number': 316} closest_ghost: red closest_distance: 52.40229002629561
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 318, 'frame_number': 318} closest_ghost: pink closest_distance: 24.166091947189145
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 320, 'frame_number': 320} closest_ghost: red closest_distance: 55.154328932550705
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 322, 'frame_number': 322} closest_ghost: cyan closest_distance: 17.88854381999832
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 324, 'frame_number': 324} closest_ghost: pink closest_distance: 18.384776310850235
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 328, 'frame_number': 328} closest_ghost: pink closest_distance: 13.601470508735444
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 332, 'frame_number': 332} closest_ghost: pink closest_distance: 11.180339887498949
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 334, 'frame_number': 334} closest_ghost: pink closest_distance: 9.486832980505138
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 337, 'frame_number': 337} closest_ghost: cyan closest_distance: 9.055385138137417
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 339, 'frame_number': 339} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 343, 'frame_number': 343} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 346, 'frame_number': 346} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 349, 'frame_number': 349} closest_ghost: cyan closest_distance: 9.055385138137417
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 352, 'frame_number': 352} closest_ghost: pink closest_distance: 13.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 356, 'frame_number': 356} closest_ghost: pink closest_distance: 16.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 359, 'frame_number': 359} closest_ghost: pink closest_distance: 20.024984394500787
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 361, 'frame_number': 361} closest_ghost: pink closest_distance: 21.02379604162864
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 365, 'frame_number': 365} closest_ghost: pink closest_distance: 23.021728866442675
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 368, 'frame_number': 368} closest_ghost: cyan closest_distance: 14.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 371, 'frame_number': 371} closest_ghost: pink closest_distance: 23.021728866442675
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 374, 'frame_number': 374} closest_ghost: pink closest_distance: 23.345235059857504
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 377, 'frame_number': 377} closest_ghost: pink closest_distance: 24.041630560342615
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 380, 'frame_number': 380} closest_ghost: orange closest_distance: 46.61544808322666
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 384, 'frame_number': 384} closest_ghost: pink closest_distance: 22.47220505424423
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 386, 'frame_number': 386} closest_ghost: orange closest_distance: 39.66106403010388
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 388, 'frame_number': 388} closest_ghost: cyan closest_distance: 23.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 391, 'frame_number': 391} closest_ghost: cyan closest_distance: 23.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 393, 'frame_number': 393} closest_ghost: pink closest_distance: 15.033296378372908
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 395, 'frame_number': 395} closest_ghost: orange closest_distance: 31.622776601683793
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 398, 'frame_number': 398} closest_ghost: orange closest_distance: 31.89043743820395
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 402, 'frame_number': 402} closest_ghost: pink closest_distance: 10.44030650891055
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 405, 'frame_number': 405} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 407, 'frame_number': 407} closest_ghost: cyan closest_distance: 19.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 410, 'frame_number': 410} closest_ghost: cyan closest_distance: 19.0
# episode: 0 action: 3 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 413, 'frame_number': 413} closest_ghost: orange closest_distance: 19.1049731745428
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 415, 'frame_number': 415} closest_ghost: cyan closest_distance: 14.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 419, 'frame_number': 419} closest_ghost: orange closest_distance: 16.278820596099706
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 423, 'frame_number': 423} closest_ghost: pink closest_distance: 10.295630140987
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 427, 'frame_number': 427} closest_ghost: pink closest_distance: 14.212670403551895
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 431, 'frame_number': 431} closest_ghost: cyan closest_distance: 12.041594578792296
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 435, 'frame_number': 435} closest_ghost: orange closest_distance: 5.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 438, 'frame_number': 438} closest_ghost: orange closest_distance: 8.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 441, 'frame_number': 441} closest_ghost: cyan closest_distance: 13.892443989449804
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 443, 'frame_number': 443} closest_ghost: cyan closest_distance: 14.866068747318506
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 447, 'frame_number': 447} closest_ghost: orange closest_distance: 14.035668847618199
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 450, 'frame_number': 450} closest_ghost: orange closest_distance: 18.027756377319946
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 454, 'frame_number': 454} closest_ghost: pink closest_distance: 23.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 458, 'frame_number': 458} closest_ghost: pink closest_distance: 23.08679276123039
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 460, 'frame_number': 460} closest_ghost: pink closest_distance: 23.345235059857504
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 463, 'frame_number': 463} closest_ghost: cyan closest_distance: 24.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 466, 'frame_number': 466} closest_ghost: pink closest_distance: 22.80350850198276
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 469, 'frame_number': 469} closest_ghost: cyan closest_distance: 29.017236257093817
# episode: 0 action: 7 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 473, 'frame_number': 473} closest_ghost: pink closest_distance: 19.4164878389476
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 476, 'frame_number': 476} closest_ghost: pink closest_distance: 19.79898987322333
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 478, 'frame_number': 478} closest_ghost: pink closest_distance: 18.384776310850235
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 482, 'frame_number': 482} closest_ghost: pink closest_distance: 17.029386365926403
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 486, 'frame_number': 486} closest_ghost: pink closest_distance: 16.278820596099706
# episode: 0 action: 5 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 489, 'frame_number': 489} closest_ghost: pink closest_distance: 14.142135623730951
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 492, 'frame_number': 492} closest_ghost: pink closest_distance: 14.212670403551895
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 495, 'frame_number': 495} closest_ghost: pink closest_distance: 12.206555615733702
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 497, 'frame_number': 497} closest_ghost: pink closest_distance: 12.529964086141668
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 500, 'frame_number': 500} closest_ghost: pink closest_distance: 13.92838827718412
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 504, 'frame_number': 504} closest_ghost: pink closest_distance: 17.26267650163207
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 508, 'frame_number': 508} closest_ghost: pink closest_distance: 19.924858845171276
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 511, 'frame_number': 511} closest_ghost: cyan closest_distance: 48.60041152089147
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 513, 'frame_number': 513} closest_ghost: cyan closest_distance: 50.44799302251776
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 515, 'frame_number': 515} closest_ghost: cyan closest_distance: 52.40229002629561
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 519, 'frame_number': 519} closest_ghost: cyan closest_distance: 54.45181356024793
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 522, 'frame_number': 522} closest_ghost: pink closest_distance: 27.202941017470888
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 525, 'frame_number': 525} closest_ghost: cyan closest_distance: 50.32891812864648
# episode: 0 action: 6 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 529, 'frame_number': 529} closest_ghost: cyan closest_distance: 45.48626166217664
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 531, 'frame_number': 531} closest_ghost: cyan closest_distance: 43.41658669218482
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 535, 'frame_number': 535} closest_ghost: pink closest_distance: 28.600699292150182
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 537, 'frame_number': 537} closest_ghost: pink closest_distance: 27.65863337187866
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 541, 'frame_number': 541} closest_ghost: pink closest_distance: 24.413111231467404
# episode: 0 action: 6 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 544, 'frame_number': 544} closest_ghost: cyan closest_distance: 38.07886552931954
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 548, 'frame_number': 548} closest_ghost: cyan closest_distance: 37.05401462729781
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 551, 'frame_number': 551} closest_ghost: pink closest_distance: 15.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 553, 'frame_number': 553} closest_ghost: pink closest_distance: 15.652475842498529
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 556, 'frame_number': 556} closest_ghost: pink closest_distance: 18.973665961010276
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 558, 'frame_number': 558} closest_ghost: pink closest_distance: 20.396078054371138
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 562, 'frame_number': 562} closest_ghost: pink closest_distance: 24.08318915758459
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 564, 'frame_number': 564} closest_ghost: pink closest_distance: 26.019223662515376
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 568, 'frame_number': 568} closest_ghost: pink closest_distance: 30.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 572, 'frame_number': 572} closest_ghost: pink closest_distance: 34.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 574, 'frame_number': 574} closest_ghost: pink closest_distance: 36.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 576, 'frame_number': 576} closest_ghost: pink closest_distance: 36.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 580, 'frame_number': 580} closest_ghost: pink closest_distance: 34.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 582, 'frame_number': 582} closest_ghost: pink closest_distance: 32.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 585, 'frame_number': 585} closest_ghost: pink closest_distance: 29.0
# episode: 0 action: 7 reward: 10.0 done: False info: {'lives': 3, 'episode_frame_number': 587, 'frame_number': 587} closest_ghost: pink closest_distance: 27.018512172212592
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 591, 'frame_number': 591} closest_ghost: pink closest_distance: 23.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 594, 'frame_number': 594} closest_ghost: pink closest_distance: 22.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 598, 'frame_number': 598} closest_ghost: pink closest_distance: 18.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 601, 'frame_number': 601} closest_ghost: pink closest_distance: 16.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 605, 'frame_number': 605} closest_ghost: pink closest_distance: 12.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 608, 'frame_number': 608} closest_ghost: pink closest_distance: 10.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 611, 'frame_number': 611} closest_ghost: pink closest_distance: 7.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 613, 'frame_number': 613} closest_ghost: pink closest_distance: 5.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 616, 'frame_number': 616} closest_ghost: red closest_distance: 45.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 618, 'frame_number': 618} closest_ghost: red closest_distance: 43.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 620, 'frame_number': 620} closest_ghost: red closest_distance: 41.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 624, 'frame_number': 624} closest_ghost: red closest_distance: 37.013511046643494
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 626, 'frame_number': 626} closest_ghost: red closest_distance: 36.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 628, 'frame_number': 628} closest_ghost: red closest_distance: 36.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 632, 'frame_number': 632} closest_ghost: red closest_distance: 37.013511046643494
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 635, 'frame_number': 635} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 639, 'frame_number': 639} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 641, 'frame_number': 641} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 645, 'frame_number': 645} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 647, 'frame_number': 647} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 650, 'frame_number': 650} closest_ghost: red closest_distance: 38.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 653, 'frame_number': 653} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 655, 'frame_number': 655} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 657, 'frame_number': 657} closest_ghost: pink closest_distance: 1.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 659, 'frame_number': 659} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 663, 'frame_number': 663} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 665, 'frame_number': 665} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 667, 'frame_number': 667} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 670, 'frame_number': 670} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 673, 'frame_number': 673} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 677, 'frame_number': 677} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 680, 'frame_number': 680} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 683, 'frame_number': 683} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 685, 'frame_number': 685} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 687, 'frame_number': 687} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 690, 'frame_number': 690} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 694, 'frame_number': 694} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 3, 'episode_frame_number': 696, 'frame_number': 696} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 699, 'frame_number': 699} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 703, 'frame_number': 703} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 706, 'frame_number': 706} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 709, 'frame_number': 709} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 711, 'frame_number': 711} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 715, 'frame_number': 715} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 718, 'frame_number': 718} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 721, 'frame_number': 721} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 725, 'frame_number': 725} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 729, 'frame_number': 729} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 731, 'frame_number': 731} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 733, 'frame_number': 733} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 736, 'frame_number': 736} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 739, 'frame_number': 739} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 743, 'frame_number': 743} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 745, 'frame_number': 745} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 747, 'frame_number': 747} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 751, 'frame_number': 751} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 754, 'frame_number': 754} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 757, 'frame_number': 757} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 761, 'frame_number': 761} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 763, 'frame_number': 763} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 766, 'frame_number': 766} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 770, 'frame_number': 770} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 772, 'frame_number': 772} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 774, 'frame_number': 774} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 778, 'frame_number': 778} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 780, 'frame_number': 780} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 782, 'frame_number': 782} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 786, 'frame_number': 786} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 789, 'frame_number': 789} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 793, 'frame_number': 793} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 796, 'frame_number': 796} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 800, 'frame_number': 800} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 802, 'frame_number': 802} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 804, 'frame_number': 804} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 806, 'frame_number': 806} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 808, 'frame_number': 808} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 811, 'frame_number': 811} closest_ghost: cyan closest_distance: 9.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 815, 'frame_number': 815} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 819, 'frame_number': 819} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 821, 'frame_number': 821} closest_ghost: orange closest_distance: 9.0
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 825, 'frame_number': 825} closest_ghost: pink closest_distance: 9.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 828, 'frame_number': 828} closest_ghost: orange closest_distance: 9.219544457292887
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 831, 'frame_number': 831} closest_ghost: orange closest_distance: 12.083045973594572
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 834, 'frame_number': 834} closest_ghost: orange closest_distance: 15.264337522473747
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 836, 'frame_number': 836} closest_ghost: cyan closest_distance: 18.788294228055936
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 838, 'frame_number': 838} closest_ghost: pink closest_distance: 16.15549442140351
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 841, 'frame_number': 841} closest_ghost: pink closest_distance: 18.027756377319946
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 845, 'frame_number': 845} closest_ghost: red closest_distance: 40.80441152620633
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 847, 'frame_number': 847} closest_ghost: cyan closest_distance: 23.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 850, 'frame_number': 850} closest_ghost: pink closest_distance: 22.0
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 854, 'frame_number': 854} closest_ghost: pink closest_distance: 23.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 857, 'frame_number': 857} closest_ghost: red closest_distance: 48.010415536631214
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 861, 'frame_number': 861} closest_ghost: red closest_distance: 48.010415536631214
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 863, 'frame_number': 863} closest_ghost: cyan closest_distance: 23.194827009486403
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 865, 'frame_number': 865} closest_ghost: red closest_distance: 48.010415536631214
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 867, 'frame_number': 867} closest_ghost: cyan closest_distance: 20.09975124224178
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 870, 'frame_number': 870} closest_ghost: pink closest_distance: 22.360679774997898
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 873, 'frame_number': 873} closest_ghost: pink closest_distance: 19.4164878389476
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 876, 'frame_number': 876} closest_ghost: pink closest_distance: 18.027756377319946
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 879, 'frame_number': 879} closest_ghost: cyan closest_distance: 14.560219778561036
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 882, 'frame_number': 882} closest_ghost: pink closest_distance: 12.041594578792296
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 885, 'frame_number': 885} closest_ghost: cyan closest_distance: 10.04987562112089
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 889, 'frame_number': 889} closest_ghost: cyan closest_distance: 10.295630140987
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 2, 'episode_frame_number': 892, 'frame_number': 892} closest_ghost: pink closest_distance: 9.486832980505138
# ...
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1793, 'frame_number': 1793} closest_ghost: orange closest_distance: 63.28506932918696
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1796, 'frame_number': 1796} closest_ghost: cyan closest_distance: 114.28473213863697
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1798, 'frame_number': 1798} closest_ghost: red closest_distance: 84.29116205154607
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1800, 'frame_number': 1800} closest_ghost: cyan closest_distance: 114.54693361238441
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1804, 'frame_number': 1804} closest_ghost: cyan closest_distance: 119.54078801814885
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1807, 'frame_number': 1807} closest_ghost: pink closest_distance: 107.80074211247342
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1811, 'frame_number': 1811} closest_ghost: pink closest_distance: 109.20164833920778
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1815, 'frame_number': 1815} closest_ghost: pink closest_distance: 109.40292500660117
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1817, 'frame_number': 1817} closest_ghost: cyan closest_distance: 123.22743201089601
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1821, 'frame_number': 1821} closest_ghost: orange closest_distance: 67.4166151627327
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1824, 'frame_number': 1824} closest_ghost: orange closest_distance: 68.94200461257273
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1828, 'frame_number': 1828} closest_ghost: red closest_distance: 68.94200461257273
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1831, 'frame_number': 1831} closest_ghost: red closest_distance: 67.06713054842886
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1835, 'frame_number': 1835} closest_ghost: pink closest_distance: 105.60303025955268
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1837, 'frame_number': 1837} closest_ghost: red closest_distance: 65.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1841, 'frame_number': 1841} closest_ghost: red closest_distance: 64.76109943476871
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1843, 'frame_number': 1843} closest_ghost: red closest_distance: 63.953107821277925
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1845, 'frame_number': 1845} closest_ghost: red closest_distance: 63.63961030678928
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1849, 'frame_number': 1849} closest_ghost: red closest_distance: 63.12685640834652
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1852, 'frame_number': 1852} closest_ghost: orange closest_distance: 61.71709649683789
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1854, 'frame_number': 1854} closest_ghost: orange closest_distance: 60.876925020897694
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1857, 'frame_number': 1857} closest_ghost: red closest_distance: 63.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1859, 'frame_number': 1859} closest_ghost: orange closest_distance: 60.81118318204309
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1862, 'frame_number': 1862} closest_ghost: orange closest_distance: 62.22539674441618
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1864, 'frame_number': 1864} closest_ghost: orange closest_distance: 63.655321851358195
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1867, 'frame_number': 1867} closest_ghost: orange closest_distance: 64.4437739428721
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1870, 'frame_number': 1870} closest_ghost: orange closest_distance: 63.702433234531945
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1872, 'frame_number': 1872} closest_ghost: orange closest_distance: 61.5223536610881
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1876, 'frame_number': 1876} closest_ghost: orange closest_distance: 56.639209034025185
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1878, 'frame_number': 1878} closest_ghost: orange closest_distance: 54.037024344425184
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1882, 'frame_number': 1882} closest_ghost: orange closest_distance: 54.405882034941776
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1886, 'frame_number': 1886} closest_ghost: red closest_distance: 54.74486277268398
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1889, 'frame_number': 1889} closest_ghost: red closest_distance: 51.97114584074513
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1891, 'frame_number': 1891} closest_ghost: red closest_distance: 50.44799302251776
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1893, 'frame_number': 1893} closest_ghost: red closest_distance: 48.76474136094644
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1895, 'frame_number': 1895} closest_ghost: red closest_distance: 47.43416490252569
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1898, 'frame_number': 1898} closest_ghost: red closest_distance: 45.221676218380054
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1900, 'frame_number': 1900} closest_ghost: red closest_distance: 43.01162633521314
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1904, 'frame_number': 1904} closest_ghost: red closest_distance: 40.85339643163099
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1907, 'frame_number': 1907} closest_ghost: red closest_distance: 36.76955262170047
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1911, 'frame_number': 1911} closest_ghost: red closest_distance: 31.953090617340916
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1914, 'frame_number': 1914} closest_ghost: red closest_distance: 32.31098884280702
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1918, 'frame_number': 1918} closest_ghost: orange closest_distance: 49.9799959983992
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1922, 'frame_number': 1922} closest_ghost: orange closest_distance: 50.92150822589606
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1924, 'frame_number': 1924} closest_ghost: orange closest_distance: 50.92150822589606
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1926, 'frame_number': 1926} closest_ghost: orange closest_distance: 49.040799340956916
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1930, 'frame_number': 1930} closest_ghost: red closest_distance: 20.518284528683193
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1934, 'frame_number': 1934} closest_ghost: red closest_distance: 15.556349186104045
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1936, 'frame_number': 1936} closest_ghost: red closest_distance: 14.142135623730951
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1940, 'frame_number': 1940} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1943, 'frame_number': 1943} closest_ghost: orange closest_distance: 34.88552708502482
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1945, 'frame_number': 1945} closest_ghost: orange closest_distance: 34.48187929913333
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1947, 'frame_number': 1947} closest_ghost: orange closest_distance: 34.48187929913333
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1951, 'frame_number': 1951} closest_ghost: orange closest_distance: 35.35533905932738
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1955, 'frame_number': 1955} closest_ghost: red closest_distance: 16.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1959, 'frame_number': 1959} closest_ghost: red closest_distance: 17.029386365926403
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1963, 'frame_number': 1963} closest_ghost: red closest_distance: 15.0
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1966, 'frame_number': 1966} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1968, 'frame_number': 1968} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1970, 'frame_number': 1970} closest_ghost: red closest_distance: 14.035668847618199
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1972, 'frame_number': 1972} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1975, 'frame_number': 1975} closest_ghost: red closest_distance: 12.041594578792296
# episode: 0 action: 1 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1977, 'frame_number': 1977} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1979, 'frame_number': 1979} closest_ghost: red closest_distance: 13.038404810405298
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1982, 'frame_number': 1982} closest_ghost: red closest_distance: 12.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1984, 'frame_number': 1984} closest_ghost: red closest_distance: 10.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1986, 'frame_number': 1986} closest_ghost: red closest_distance: 6.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1990, 'frame_number': 1990} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1994, 'frame_number': 1994} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1996, 'frame_number': 1996} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 1999, 'frame_number': 1999} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2003, 'frame_number': 2003} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2006, 'frame_number': 2006} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2010, 'frame_number': 2010} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2013, 'frame_number': 2013} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2015, 'frame_number': 2015} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2019, 'frame_number': 2019} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2022, 'frame_number': 2022} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2025, 'frame_number': 2025} closest_ghost: red closest_distance: 1.0
# episode: 0 action: 4 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2029, 'frame_number': 2029} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2031, 'frame_number': 2031} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2034, 'frame_number': 2034} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 3 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2038, 'frame_number': 2038} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 0 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2042, 'frame_number': 2042} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2044, 'frame_number': 2044} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2048, 'frame_number': 2048} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 6 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2052, 'frame_number': 2052} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 8 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2056, 'frame_number': 2056} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 2 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2060, 'frame_number': 2060} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 7 reward: 0.0 done: False info: {'lives': 1, 'episode_frame_number': 2064, 'frame_number': 2064} closest_ghost: None closest_distance: 1000000
# episode: 0 action: 5 reward: 0.0 done: False info: {'lives': 0, 'episode_frame_number': 2065, 'frame_number': 2065} closest_ghost: None closest_distance: 1000000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 game = Pacman()
# ----> 2 game.run(1)
#
# Cell In[3], line 68, in Pacman.run(self, num_episodes)
#      66 if terminated or truncated or lives == 0:
#      67     done = True;
# ---> 68     rewards.append(reward_sum)
#      69     print(f"episode: {episode} reward = {reward_sum}")
#      70     observation, info = self.env.reset()
#
# NameError: name 'reward_sum' is not defined

# %%
with np.printoptions(threshold=np.inf):
    print(distance)
# Out:
# ('pink', 9.0)
